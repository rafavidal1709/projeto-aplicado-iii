# %% [markdown]
# <a href="https://colab.research.google.com/github/rafavidal1709/projeto-aplicado-iii/blob/main/Longformer_classifica%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Primeiros testes com o Longformer
#
# Duas formas de gerar um embedding com tamanho padronizado para representar toda a semântica de um texto: a camada de atenção global e a média dos tokens de saída.

# %%
import torch
from transformers import LongformerTokenizer, LongformerModel

# Verificar se a GPU está disponível
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Liberar memória da GPU, se necessário
torch.cuda.empty_cache()

# Carregar o modelo e o tokenizador Longformer-large
tokenizer = LongformerTokenizer.from_pretrained("allenai/longformer-large-4096")
model = LongformerModel.from_pretrained("allenai/longformer-large-4096").to(device)

# Habilitar gradient checkpointing para economizar memória
model.gradient_checkpointing_enable()

# Texto de exemplo
text = "Exemplo de texto longo que queremos classificar usando Longformer."

# Reduzir o comprimento máximo, se possível
inputs = tokenizer(text, return_tensors="pt", truncation=True, padding="max_length", max_length=2048)

# Definir a máscara de atenção: 1 para global attention no primeiro token (ou outro token especial)
attention_mask = torch.ones(inputs['input_ids'].shape, dtype=torch.long).to(device)  # Enviar para GPU
global_attention_mask = torch.zeros(inputs['input_ids'].shape, dtype=torch.long).to(device)  # Enviar para GPU
global_attention_mask[:, 0] = 1  # Dar atenção global ao primeiro token (posição 0)

# Enviar os inputs para a GPU
inputs = {key: value.to(device) for key, value in inputs.items()}

# Passar pelo modelo com a máscara de atenção global
outputs = model(input_ids=inputs['input_ids'], attention_mask=attention_mask, global_attention_mask=global_attention_mask)

# Extraímos o embedding do primeiro token (com atenção global)
global_attention_embedding = outputs.last_hidden_state[:, 0, :]  # Primeiro token com global attention

# Fazer a média dos embeddings de todos os tokens (global pooling)
output_mean_embedding = torch.mean(outputs.last_hidden_state, dim=1)

# Verificar o formato dos embeddings
print('\n', global_attention_embedding.shape, '\n', output_mean_embedding.shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
#  torch.Size([1, 1024])
#  torch.Size([1, 1024])

# %% [markdown]
# # Testando a capacidade de gerar resposta do Longformer

# %%
import torch
from transformers import AutoTokenizer, AutoModelForQuestionAnswering
from torch.cuda.amp import autocast

# Verificar se a GPU está disponível
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Liberar memória da GPU
torch.cuda.empty_cache()

# Carregar um modelo e tokenizer compatíveis com o português
tokenizer = AutoTokenizer.from_pretrained('pierreguillou/bert-large-cased-squad-v1.1-portuguese')
model = AutoModelForQuestionAnswering.from_pretrained('pierreguillou/bert-large-cased-squad-v1.1-portuguese').to(device)

# Contexto detalhado em português
context = """
Longformer é um modelo de processamento de linguagem natural desenvolvido para lidar com grandes quantidades de texto.
Ele utiliza uma atenção local eficiente que permite processar até 4096 tokens em uma única passagem, o que é significativamente
maior do que outros modelos tradicionais. O Longformer é projetado para tarefas de leitura de documentos longos, perguntas e respostas,
sumarização, entre outras.
"""

# Pergunta em português
question = "Para que o Longformer foi projetado?"

# Tokenizar a pergunta e o contexto
inputs = tokenizer(question, context, return_tensors="pt", truncation=True, padding=True, max_length=512)

# Enviar os inputs para a GPU
inputs = {key: value.to(device) for key, value in inputs.items()}

# Obter a resposta do modelo usando o autocast atualizado
with torch.cuda.amp.autocast():
    outputs = model(**inputs)

start_scores = outputs.start_logits
end_scores = outputs.end_logits

# Determinar os índices de início e fim da resposta
start_index = torch.argmax(start_scores)
end_index = torch.argmax(end_scores)

print(f"Start index: {start_index}, End index: {end_index}")

# Garantir que os índices estão corretos
if start_index <= end_index:
    # Decodificar a resposta
    answer = tokenizer.decode(inputs['input_ids'][0][start_index:end_index+1], skip_special_tokens=True, clean_up_tokenization_spaces=True)
else:
    answer = "Não foi possível encontrar uma resposta."

print(f"Resposta: {answer}")
# Out:
# Start index: 73, End index: 76
# Resposta: leitura de documentos longos
# <ipython-input-4-f98b3668b118>:33: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():

# %% [markdown]
# # Aplicando no nosso problema de classificação
#
# Carregando o arquivo de amostras e reduzindo a uma quantidade menor

# %%
import json
import random

# Carregar o arquivo JSON
with open('/content/realistic_denuncias_ambientais_5000_v2.json') as file:
    data = json.load(file)

# Selecionar 100 amostras aleatórias
sampled_data = random.sample(data, 200)

# Exibir as primeiras amostras selecionadas
sampled_data
# Out:
# [{'text': 'O gado está destruindo a nascente em Nordeste, pisoteando a área e acabando com a vegetação ao redor.',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'A nascente da fazenda Fazenda Nova está sendo contaminada pelo gado, que está pisoteando a margem.',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Queimaram tudo aqui na fazenda do Fazenda Esperança pra aumentar o espaço pro gado. Já aconteceu ano passado.',
#   'tags': ['incendio_criminoso', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Trabalhadores rurais estão aplicando agrotóxicos sem EPI na fazenda Sítio do João. Estão expostos a substâncias nocivas.',
#   'tags': ['trabalhadores_sem_epi', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Trabalhadores rurais estão aplicando agrotóxicos sem EPI na fazenda Sítio da Paz. Estão expostos a substâncias nocivas.',
#   'tags': ['trabalhadores_sem_epi', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Tão trabalhando sem proteção nenhuma na fazenda Fazenda Bela Vista, jogando veneno na lavoura. É um perigo!',
#   'tags': ['trabalhadores_sem_epi', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Aqui na região de Sul de Minas, as nascentes tão todas sendo envenenadas pelos agrotóxicos que jogam na roça.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'Foi registrada a contaminação de uma nascente por agrotóxicos usados em plantações de eucalipto em Cuiabá.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'A nascente da fazenda Fazenda Nova está sendo contaminada pelo gado, que está pisoteando a margem.',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Incêndio criminoso está ocorrendo agora em uma área de pastagem no interior de Rio Branco, afetando a vegetação nativa.',
#   'tags': ['queimadas', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Na lavoura de milho em Campo Grande, os trabalhadores estão sem nenhum equipamento de proteção para aplicar os venenos.',
#   'tags': ['trabalhadores_sem_epi', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Queimada ilegal em uma fazenda próxima a Sudeste, está destruindo a flora local e ameaçando animais selvagens.',
#   'tags': ['queimadas', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'A beira do córrego em Vitória foi desmatada para plantar cana-de-açúcar, o que está comprometendo a vegetação.',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Tão trabalhando sem proteção nenhuma na fazenda Fazenda Esperança, jogando veneno na lavoura. É um perigo!',
#   'tags': ['trabalhadores_sem_epi', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'O gado tá bebendo água diretamente do rio Doce, contaminando e pisoteando a margem.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'A nascente da fazenda Fazenda Nova está sendo contaminada pelo gado, que está pisoteando a margem.',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Detectamos corte ilegal de cedro em APP no interior de Rio Branco, causando grande prejuízo à vegetação local.',
#   'tags': ['corte_arvore', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Foi identificado o corte de pau-brasil em uma área protegida na região de Sul de Minas.',
#   'tags': ['corte_arvore', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Detectamos corte ilegal de cedro em APP no interior de Campo Grande, causando grande prejuízo à vegetação local.',
#   'tags': ['corte_arvore', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'As nascentes na fazenda Fazenda Esperança estão sendo contaminadas pelo uso indiscriminado de agrotóxicos.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'Aqui na fazenda Fazenda Bela Vista, desmataram a nascente para plantar milho. Isso vai secar tudo!',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Foi registrado o desmatamento no topo de morro em Nordeste, comprometendo uma área de preservação permanente.',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'O gado tá bebendo água diretamente do rio Paraná, contaminando e pisoteando a margem.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Incêndio criminoso está ocorrendo agora em uma área de pastagem no interior de Rio Branco, afetando a vegetação nativa.',
#   'tags': ['queimadas', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Tá todo mundo ficando doente aqui com esse veneno que jogam nas plantações perto da vila.',
#   'tags': ['veneno_agricultura', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'O gado tá bebendo água diretamente do rio Xingu, contaminando e pisoteando a margem.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'O gado está destruindo a nascente em Nordeste, pisoteando a área e acabando com a vegetação ao redor.',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Aqui em Centro-Oeste, o veneno que jogam nas plantações tá indo parar nas casas do pessoal.',
#   'tags': ['agrotoxico_proximo_residencias',
#    'APP',
#    'impacto ambiental',
#    'urgente']},
#  {'text': 'Queimaram tudo aqui na fazenda do Fazenda Bela Vista pra aumentar o espaço pro gado. Já aconteceu ano passado.',
#   'tags': ['incendio_criminoso', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Na lavoura de trigo em Cuiabá, os trabalhadores estão sem nenhum equipamento de proteção para aplicar os venenos.',
#   'tags': ['trabalhadores_sem_epi', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Foi registrado o desmatamento no topo de morro em Centro-Oeste, comprometendo uma área de preservação permanente.',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Vimos o gado pisoteando a nascente na fazenda Fazenda Bela Vista. A água já está turva e sem condições de uso.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'A nascente da fazenda Fazenda Esperança está sendo contaminada pelo gado, que está pisoteando a margem.',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'A beira do córrego em Vitória foi desmatada para plantar cana-de-açúcar, o que está comprometendo a vegetação.',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Aqui na região de Nordeste, as nascentes tão todas sendo envenenadas pelos agrotóxicos que jogam na roça.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'A nascente da fazenda Sítio da Paz está sendo contaminada pelo gado, que está pisoteando a margem.',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'A beira do córrego em Vitória foi desmatada para plantar trigo, o que está comprometendo a vegetação.',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Foi registrado o desmatamento no topo de morro em Nordeste, comprometendo uma área de preservação permanente.',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Na lavoura de trigo em Vitória, os trabalhadores estão sem nenhum equipamento de proteção para aplicar os venenos.',
#   'tags': ['trabalhadores_sem_epi', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'A nascente da fazenda Sítio da Paz está sendo contaminada pelo gado, que está pisoteando a margem.',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'O gado está destruindo a nascente em Sudeste, pisoteando a área e acabando com a vegetação ao redor.',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Detectamos corte ilegal de cedro em APP no interior de Cuiabá, causando grande prejuízo à vegetação local.',
#   'tags': ['corte_arvore', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Foi registrado o desmatamento no topo de morro em Centro-Oeste, comprometendo uma área de preservação permanente.',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Tão trabalhando sem proteção nenhuma na fazenda Fazenda Esperança, jogando veneno na lavoura. É um perigo!',
#   'tags': ['trabalhadores_sem_epi', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Os moradores de Campo Grande estão passando mal por conta da pulverização de venenos na lavoura próxima.',
#   'tags': ['veneno_agricultura', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'As nascentes na fazenda Fazenda Nova estão sendo contaminadas pelo uso indiscriminado de agrotóxicos.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'Foi registrada a contaminação de uma nascente por agrotóxicos usados em plantações de soja em Vitória.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'Árvores de mogno estão sendo ilegalmente cortadas na área de preservação próxima ao rio Xingu.',
#   'tags': ['corte_arvore', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Foi registrado o desmatamento no topo de morro em Sudeste, comprometendo uma área de preservação permanente.',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'As nascentes na fazenda Fazenda Nova estão sendo contaminadas pelo uso indiscriminado de agrotóxicos.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'O gado tá bebendo água diretamente do rio Doce, contaminando e pisoteando a margem.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'A pulverização de agrotóxicos nas fazendas de Sudeste está causando problemas respiratórios na comunidade local.',
#   'tags': ['veneno_agricultura', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Foi registrado o desmatamento no topo de morro em Sudeste, comprometendo uma área de preservação permanente.',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'As nascentes na fazenda Sítio da Paz estão sendo contaminadas pelo uso indiscriminado de agrotóxicos.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'Detectamos corte ilegal de cedro em APP no interior de Rio Branco, causando grande prejuízo à vegetação local.',
#   'tags': ['corte_arvore', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'O uso de agrotóxicos nas plantações perto das casas em Campo Grande está colocando os moradores em risco.',
#   'tags': ['agrotoxico_proximo_residencias',
#    'APP',
#    'impacto ambiental',
#    'urgente']},
#  {'text': 'O gado está destruindo a nascente em Centro-Oeste, pisoteando a área e acabando com a vegetação ao redor.',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Queimada ilegal em uma fazenda próxima a Centro-Oeste, está destruindo a flora local e ameaçando animais selvagens.',
#   'tags': ['queimadas', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'A nascente da fazenda Fazenda Nova está sendo contaminada pelo gado, que está pisoteando a margem.',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'O uso de agrotóxicos nas plantações perto das casas em Rio Branco está colocando os moradores em risco.',
#   'tags': ['agrotoxico_proximo_residencias',
#    'APP',
#    'impacto ambiental',
#    'urgente']},
#  {'text': 'O gado está destruindo a nascente em Sul de Minas, pisoteando a área e acabando com a vegetação ao redor.',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Os bois tão destruindo a nascente aqui, e não tem mais água limpa!',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Em 2020, houve uma queimada criminosa em Rio Branco que devastou uma área de preservação permanente.',
#   'tags': ['queimadas', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'O gado tá bebendo água diretamente do rio Paraná, contaminando e pisoteando a margem.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Os bois tão destruindo a nascente aqui, e não tem mais água limpa!',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Detectamos corte ilegal de cedro em APP no interior de Campo Grande, causando grande prejuízo à vegetação local.',
#   'tags': ['corte_arvore', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Foi registrada a contaminação de uma nascente por agrotóxicos usados em plantações de eucalipto em Vitória.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'urgente']},
#  {'text': 'Foi registrada a contaminação de uma nascente por agrotóxicos usados em plantações de eucalipto em Rio Branco.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'Foi registrada a contaminação de uma nascente por agrotóxicos usados em plantações de eucalipto em Uberlândia.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'urgente']},
#  {'text': 'A beira do córrego em Rio Branco foi desmatada para plantar eucalipto, o que está comprometendo a vegetação.',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Na lavoura de soja em Campo Grande, os trabalhadores estão sem nenhum equipamento de proteção para aplicar os venenos.',
#   'tags': ['trabalhadores_sem_epi', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Foi identificado o corte de pau-brasil em uma área protegida na região de Sul de Minas.',
#   'tags': ['corte_arvore', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Árvores de mogno estão sendo ilegalmente cortadas na área de preservação próxima ao rio Doce.',
#   'tags': ['corte_arvore', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'A nascente da fazenda Fazenda Esperança está sendo contaminada pelo gado, que está pisoteando a margem.',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Árvores de mogno estão sendo ilegalmente cortadas na área de preservação próxima ao rio Doce.',
#   'tags': ['corte_arvore', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'A pulverização de agrotóxicos nas fazendas de Centro-Oeste está causando problemas respiratórios na comunidade local.',
#   'tags': ['veneno_agricultura', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Queimada ilegal em uma fazenda próxima a Norte, está destruindo a flora local e ameaçando animais selvagens.',
#   'tags': ['queimadas', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'O gado tá bebendo água diretamente do rio Xingu, contaminando e pisoteando a margem.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Foi registrado o desmatamento no topo de morro em Sudeste, comprometendo uma área de preservação permanente.',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Detectamos corte ilegal de cedro em APP no interior de Campo Grande, causando grande prejuízo à vegetação local.',
#   'tags': ['corte_arvore', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Em 2020, houve uma queimada criminosa em Rio Branco que devastou uma área de preservação permanente.',
#   'tags': ['queimadas', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Queimaram tudo aqui na fazenda do Sítio da Paz pra aumentar o espaço pro gado. Já aconteceu ano passado.',
#   'tags': ['incendio_criminoso', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Aqui no Fazenda Esperança, o gado tá bebendo direto do rio, e a vegetação ciliar já foi toda destruída.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'A pulverização de agrotóxicos nas fazendas de Centro-Oeste está causando problemas respiratórios na comunidade local.',
#   'tags': ['veneno_agricultura', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'O uso de agrotóxicos nas plantações perto das casas em Rio Branco está colocando os moradores em risco.',
#   'tags': ['agrotoxico_proximo_residencias',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'Queimaram tudo aqui na fazenda do Fazenda Bela Vista pra aumentar o espaço pro gado. Já aconteceu ano passado.',
#   'tags': ['incendio_criminoso', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Aqui na fazenda Fazenda Nova, desmataram a nascente para plantar milho. Isso vai secar tudo!',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Aqui na região de Nordeste, as nascentes tão todas sendo envenenadas pelos agrotóxicos que jogam na roça.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'urgente']},
#  {'text': 'A nascente da fazenda Sítio do João está sendo contaminada pelo gado, que está pisoteando a margem.',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Foi registrada a contaminação de uma nascente por agrotóxicos usados em plantações de trigo em Cuiabá.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'Detectamos corte ilegal de cedro em APP no interior de Uberlândia, causando grande prejuízo à vegetação local.',
#   'tags': ['corte_arvore', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'A pulverização de agrotóxicos nas fazendas de Centro-Oeste está causando problemas respiratórios na comunidade local.',
#   'tags': ['veneno_agricultura', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Aqui no Sítio da Paz, o gado tá bebendo direto do rio, e a vegetação ciliar já foi toda destruída.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Vimos o gado pisoteando a nascente na fazenda Fazenda Nova. A água já está turva e sem condições de uso.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'O gado tá bebendo água diretamente do rio São Francisco, contaminando e pisoteando a margem.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Foi registrado o desmatamento no topo de morro em Centro-Oeste, comprometendo uma área de preservação permanente.',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'As lavouras de soja tão sendo pulverizadas com veneno perto das casas. A saúde de todo mundo tá em risco!',
#   'tags': ['agrotoxico_proximo_residencias',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'Vimos o gado pisoteando a nascente na fazenda Fazenda Esperança. A água já está turva e sem condições de uso.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Foi registrado o desmatamento no topo de morro em Centro-Oeste, comprometendo uma área de preservação permanente.',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Trabalhadores rurais estão aplicando agrotóxicos sem EPI na fazenda Sítio da Paz. Estão expostos a substâncias nocivas.',
#   'tags': ['trabalhadores_sem_epi', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Em 2020, houve uma queimada criminosa em Cuiabá que devastou uma área de preservação permanente.',
#   'tags': ['queimadas', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Incêndio proposital para aumentar pastagens foi registrado na fazenda Fazenda Bela Vista, perto do rio Doce.',
#   'tags': ['incendio_criminoso', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'O gado está destruindo a nascente em Nordeste, pisoteando a área e acabando com a vegetação ao redor.',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Tão trabalhando sem proteção nenhuma na fazenda Sítio do João, jogando veneno na lavoura. É um perigo!',
#   'tags': ['trabalhadores_sem_epi', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Incêndio criminoso está ocorrendo agora em uma área de pastagem no interior de Campo Grande, afetando a vegetação nativa.',
#   'tags': ['queimadas', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'A beira do córrego em Campo Grande foi desmatada para plantar trigo, o que está comprometendo a vegetação.',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'O gado está destruindo a nascente em Sul de Minas, pisoteando a área e acabando com a vegetação ao redor.',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'O uso de agrotóxicos nas plantações perto das casas em Rio Branco está colocando os moradores em risco.',
#   'tags': ['agrotoxico_proximo_residencias',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'Queimaram tudo aqui na fazenda do Sítio do João pra aumentar o espaço pro gado. Já aconteceu ano passado.',
#   'tags': ['incendio_criminoso', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Queimaram tudo aqui na fazenda do Fazenda Esperança pra aumentar o espaço pro gado. Já aconteceu ano passado.',
#   'tags': ['incendio_criminoso', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Aqui em Norte, o veneno que jogam nas plantações tá indo parar nas casas do pessoal.',
#   'tags': ['agrotoxico_proximo_residencias',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'Fazendeiros estão usando fogo para ampliar as pastagens na região de Sudeste. A situação é grave!',
#   'tags': ['incendio_criminoso', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Incêndio criminoso está ocorrendo agora em uma área de pastagem no interior de Uberlândia, afetando a vegetação nativa.',
#   'tags': ['queimadas', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Árvores de mogno estão sendo ilegalmente cortadas na área de preservação próxima ao rio Doce.',
#   'tags': ['corte_arvore', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'O gado está destruindo a nascente em Norte, pisoteando a área e acabando com a vegetação ao redor.',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Os moradores de Cuiabá estão passando mal por conta da pulverização de venenos na lavoura próxima.',
#   'tags': ['veneno_agricultura', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'As lavouras de soja tão sendo pulverizadas com veneno perto das casas. A saúde de todo mundo tá em risco!',
#   'tags': ['agrotoxico_proximo_residencias',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'Tá todo mundo ficando doente aqui com esse veneno que jogam nas plantações perto da vila.',
#   'tags': ['veneno_agricultura', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Vimos o gado pisoteando a nascente na fazenda Sítio do João. A água já está turva e sem condições de uso.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'O uso de agrotóxicos nas plantações perto das casas em Campo Grande está colocando os moradores em risco.',
#   'tags': ['agrotoxico_proximo_residencias',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'As nascentes na fazenda Fazenda Esperança estão sendo contaminadas pelo uso indiscriminado de agrotóxicos.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'urgente']},
#  {'text': 'Fazendeiros estão usando fogo para ampliar as pastagens na região de Nordeste. A situação é grave!',
#   'tags': ['incendio_criminoso', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Aqui em Norte, o veneno que jogam nas plantações tá indo parar nas casas do pessoal.',
#   'tags': ['agrotoxico_proximo_residencias',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'O gado tá bebendo água diretamente do rio Paraná, contaminando e pisoteando a margem.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'As lavouras de eucalipto tão sendo pulverizadas com veneno perto das casas. A saúde de todo mundo tá em risco!',
#   'tags': ['agrotoxico_proximo_residencias',
#    'APP',
#    'impacto ambiental',
#    'urgente']},
#  {'text': 'Queimaram tudo aqui na fazenda do Fazenda Bela Vista pra aumentar o espaço pro gado. Já aconteceu ano passado.',
#   'tags': ['incendio_criminoso', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'O gado tá bebendo água diretamente do rio Xingu, contaminando e pisoteando a margem.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'As nascentes na fazenda Fazenda Bela Vista estão sendo contaminadas pelo uso indiscriminado de agrotóxicos.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'urgente']},
#  {'text': 'Queimaram tudo aqui na fazenda do Fazenda Bela Vista pra aumentar o espaço pro gado. Já aconteceu ano passado.',
#   'tags': ['incendio_criminoso', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Aqui em Sul de Minas, o veneno que jogam nas plantações tá indo parar nas casas do pessoal.',
#   'tags': ['agrotoxico_proximo_residencias',
#    'APP',
#    'impacto ambiental',
#    'urgente']},
#  {'text': 'Foi registrado o desmatamento no topo de morro em Sudeste, comprometendo uma área de preservação permanente.',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Foi identificado o corte de pau-brasil em uma área protegida na região de Sudeste.',
#   'tags': ['corte_arvore', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Aqui no Fazenda Bela Vista, o gado tá bebendo direto do rio, e a vegetação ciliar já foi toda destruída.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Na lavoura de soja em Campo Grande, os trabalhadores estão sem nenhum equipamento de proteção para aplicar os venenos.',
#   'tags': ['trabalhadores_sem_epi', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Na lavoura de milho em Uberlândia, os trabalhadores estão sem nenhum equipamento de proteção para aplicar os venenos.',
#   'tags': ['trabalhadores_sem_epi', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Fazendeiros estão usando fogo para ampliar as pastagens na região de Sul de Minas. A situação é grave!',
#   'tags': ['incendio_criminoso', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'A beira do córrego em Campo Grande foi desmatada para plantar eucalipto, o que está comprometendo a vegetação.',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Aqui na fazenda Sítio da Paz, desmataram a nascente para plantar milho. Isso vai secar tudo!',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'As nascentes na fazenda Fazenda Esperança estão sendo contaminadas pelo uso indiscriminado de agrotóxicos.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'Tão trabalhando sem proteção nenhuma na fazenda Sítio da Paz, jogando veneno na lavoura. É um perigo!',
#   'tags': ['trabalhadores_sem_epi', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Trabalhadores rurais estão aplicando agrotóxicos sem EPI na fazenda Sítio da Paz. Estão expostos a substâncias nocivas.',
#   'tags': ['trabalhadores_sem_epi', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Os bois tão destruindo a nascente aqui, e não tem mais água limpa!',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Em 2020, houve uma queimada criminosa em Vitória que devastou uma área de preservação permanente.',
#   'tags': ['queimadas', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Queimaram tudo aqui na fazenda do Fazenda Bela Vista pra aumentar o espaço pro gado. Já aconteceu ano passado.',
#   'tags': ['incendio_criminoso', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Foi registrada a contaminação de uma nascente por agrotóxicos usados em plantações de cana-de-açúcar em Rio Branco.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'A nascente da fazenda Sítio do João está sendo contaminada pelo gado, que está pisoteando a margem.',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Queimaram tudo aqui na fazenda do Sítio da Paz pra aumentar o espaço pro gado. Já aconteceu ano passado.',
#   'tags': ['incendio_criminoso', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Detectamos corte ilegal de cedro em APP no interior de Cuiabá, causando grande prejuízo à vegetação local.',
#   'tags': ['corte_arvore', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Em 2020, houve uma queimada criminosa em Uberlândia que devastou uma área de preservação permanente.',
#   'tags': ['queimadas', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Foi identificado o corte de pau-brasil em uma área protegida na região de Centro-Oeste.',
#   'tags': ['corte_arvore', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Incêndio proposital para aumentar pastagens foi registrado na fazenda Fazenda Esperança, perto do rio Doce.',
#   'tags': ['incendio_criminoso', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Foi registrada a contaminação de uma nascente por agrotóxicos usados em plantações de eucalipto em Campo Grande.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'Queimaram tudo aqui na fazenda do Sítio do João pra aumentar o espaço pro gado. Já aconteceu ano passado.',
#   'tags': ['incendio_criminoso', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'O gado está destruindo a nascente em Sudeste, pisoteando a área e acabando com a vegetação ao redor.',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Incêndio criminoso está ocorrendo agora em uma área de pastagem no interior de Vitória, afetando a vegetação nativa.',
#   'tags': ['queimadas', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Foi identificado o corte de pau-brasil em uma área protegida na região de Norte.',
#   'tags': ['corte_arvore', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'O gado tá bebendo água diretamente do rio Doce, contaminando e pisoteando a margem.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Foi identificado o corte de pau-brasil em uma área protegida na região de Norte.',
#   'tags': ['corte_arvore', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Em 2020, houve uma queimada criminosa em Rio Branco que devastou uma área de preservação permanente.',
#   'tags': ['queimadas', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Aqui em Sul de Minas, o veneno que jogam nas plantações tá indo parar nas casas do pessoal.',
#   'tags': ['agrotoxico_proximo_residencias',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'Na lavoura de soja em Rio Branco, os trabalhadores estão sem nenhum equipamento de proteção para aplicar os venenos.',
#   'tags': ['trabalhadores_sem_epi', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Os moradores de Cuiabá estão passando mal por conta da pulverização de venenos na lavoura próxima.',
#   'tags': ['veneno_agricultura', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Aqui na fazenda Fazenda Nova, desmataram a nascente para plantar milho. Isso vai secar tudo!',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Na lavoura de milho em Rio Branco, os trabalhadores estão sem nenhum equipamento de proteção para aplicar os venenos.',
#   'tags': ['trabalhadores_sem_epi', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Queimada ilegal em uma fazenda próxima a Nordeste, está destruindo a flora local e ameaçando animais selvagens.',
#   'tags': ['queimadas', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Na lavoura de trigo em Campo Grande, os trabalhadores estão sem nenhum equipamento de proteção para aplicar os venenos.',
#   'tags': ['trabalhadores_sem_epi', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Queimaram tudo aqui na fazenda do Fazenda Esperança pra aumentar o espaço pro gado. Já aconteceu ano passado.',
#   'tags': ['incendio_criminoso', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Aqui no Fazenda Nova, o gado tá bebendo direto do rio, e a vegetação ciliar já foi toda destruída.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Foi registrado o desmatamento no topo de morro em Norte, comprometendo uma área de preservação permanente.',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'O gado tá bebendo água diretamente do rio Doce, contaminando e pisoteando a margem.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Foi registrado o desmatamento no topo de morro em Norte, comprometendo uma área de preservação permanente.',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Detectamos corte ilegal de cedro em APP no interior de Vitória, causando grande prejuízo à vegetação local.',
#   'tags': ['corte_arvore', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'As lavouras de cana-de-açúcar tão sendo pulverizadas com veneno perto das casas. A saúde de todo mundo tá em risco!',
#   'tags': ['agrotoxico_proximo_residencias',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'Aqui no Sítio do João, o gado tá bebendo direto do rio, e a vegetação ciliar já foi toda destruída.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Na lavoura de eucalipto em Rio Branco, os trabalhadores estão sem nenhum equipamento de proteção para aplicar os venenos.',
#   'tags': ['trabalhadores_sem_epi', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'A pulverização de agrotóxicos nas fazendas de Sul de Minas está causando problemas respiratórios na comunidade local.',
#   'tags': ['veneno_agricultura', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Aqui na fazenda Fazenda Nova, desmataram a nascente para plantar milho. Isso vai secar tudo!',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Queimada ilegal em uma fazenda próxima a Norte, está destruindo a flora local e ameaçando animais selvagens.',
#   'tags': ['queimadas', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Tá todo mundo ficando doente aqui com esse veneno que jogam nas plantações perto da vila.',
#   'tags': ['veneno_agricultura', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'O gado tá bebendo água diretamente do rio São Francisco, contaminando e pisoteando a margem.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'A beira do córrego em Cuiabá foi desmatada para plantar milho, o que está comprometendo a vegetação.',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'As nascentes na fazenda Fazenda Bela Vista estão sendo contaminadas pelo uso indiscriminado de agrotóxicos.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'urgente']},
#  {'text': 'O uso de agrotóxicos nas plantações perto das casas em Uberlândia está colocando os moradores em risco.',
#   'tags': ['agrotoxico_proximo_residencias',
#    'APP',
#    'impacto ambiental',
#    'urgente']},
#  {'text': 'Tão trabalhando sem proteção nenhuma na fazenda Sítio do João, jogando veneno na lavoura. É um perigo!',
#   'tags': ['trabalhadores_sem_epi', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Em 2020, houve uma queimada criminosa em Rio Branco que devastou uma área de preservação permanente.',
#   'tags': ['queimadas', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'A beira do córrego em Vitória foi desmatada para plantar cana-de-açúcar, o que está comprometendo a vegetação.',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Detectamos corte ilegal de cedro em APP no interior de Uberlândia, causando grande prejuízo à vegetação local.',
#   'tags': ['corte_arvore', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Vimos o gado pisoteando a nascente na fazenda Sítio do João. A água já está turva e sem condições de uso.',
#   'tags': ['gado_rio', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Aqui em Sudeste, o veneno que jogam nas plantações tá indo parar nas casas do pessoal.',
#   'tags': ['agrotoxico_proximo_residencias',
#    'APP',
#    'impacto ambiental',
#    'urgente']},
#  {'text': 'A nascente da fazenda Fazenda Bela Vista está sendo contaminada pelo gado, que está pisoteando a margem.',
#   'tags': ['pisoteamento_nascente', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'As nascentes na fazenda Sítio do João estão sendo contaminadas pelo uso indiscriminado de agrotóxicos.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'urgente']},
#  {'text': 'Os moradores de Campo Grande estão passando mal por conta da pulverização de venenos na lavoura próxima.',
#   'tags': ['veneno_agricultura', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Na lavoura de soja em Rio Branco, os trabalhadores estão sem nenhum equipamento de proteção para aplicar os venenos.',
#   'tags': ['trabalhadores_sem_epi', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Aqui na fazenda Sítio da Paz, desmataram a nascente para plantar milho. Isso vai secar tudo!',
#   'tags': ['uso_indev_app', 'APP', 'impacto ambiental', 'urgente']},
#  {'text': 'Foi identificado o corte de pau-brasil em uma área protegida na região de Sul de Minas.',
#   'tags': ['corte_arvore', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'Queimaram tudo aqui na fazenda do Fazenda Nova pra aumentar o espaço pro gado. Já aconteceu ano passado.',
#   'tags': ['incendio_criminoso', 'APP', 'impacto ambiental', 'já ocorreu']},
#  {'text': 'As nascentes na fazenda Sítio da Paz estão sendo contaminadas pelo uso indiscriminado de agrotóxicos.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'As lavouras de milho tão sendo pulverizadas com veneno perto das casas. A saúde de todo mundo tá em risco!',
#   'tags': ['agrotoxico_proximo_residencias',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'As lavouras de milho tão sendo pulverizadas com veneno perto das casas. A saúde de todo mundo tá em risco!',
#   'tags': ['agrotoxico_proximo_residencias',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']},
#  {'text': 'As nascentes na fazenda Sítio do João estão sendo contaminadas pelo uso indiscriminado de agrotóxicos.',
#   'tags': ['contaminacao_nascente_agrotoxico',
#    'APP',
#    'impacto ambiental',
#    'já ocorreu']}]

# %% [markdown]
# Gerando os embeddings para cada amostra

# %%
import torch
from transformers import LongformerTokenizer, LongformerModel

# Verificar se a GPU está disponível
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Liberar memória da GPU, se necessário
torch.cuda.empty_cache()

# Carregar o modelo e o tokenizador Longformer-large
tokenizer = LongformerTokenizer.from_pretrained("allenai/longformer-large-4096")
model = LongformerModel.from_pretrained("allenai/longformer-large-4096").to(device)

# Habilitar gradient checkpointing para economizar memória
model.gradient_checkpointing_enable()

def process_text(text):
    with torch.no_grad():  # Desabilitar o cálculo de gradientes
        # Reduzir o comprimento máximo, se possível
        inputs = tokenizer(text, return_tensors="pt", truncation=True, padding="max_length", max_length=2048)

        # Definir a máscara de atenção: 1 para global attention no primeiro token (ou outro token especial)
        attention_mask = torch.ones(inputs['input_ids'].shape, dtype=torch.long).to(device)  # Enviar para GPU
        global_attention_mask = torch.zeros(inputs['input_ids'].shape, dtype=torch.long).to(device)  # Enviar para GPU
        global_attention_mask[:, 0] = 1  # Dar atenção global ao primeiro token (posição 0)

        # Enviar os inputs para a GPU
        inputs = {key: value.to(device) for key, value in inputs.items()}

        # Passar pelo modelo com a máscara de atenção global
        outputs = model(input_ids=inputs['input_ids'], attention_mask=attention_mask, global_attention_mask=global_attention_mask)

        # Extraímos o embedding do primeiro token (com atenção global)
        global_attention_embedding = outputs.last_hidden_state[:, 0, :]  # Primeiro token com global attention

        # Fazer a média dos embeddings de todos os tokens (global pooling)
        output_mean_embedding = torch.mean(outputs.last_hidden_state, dim=1)

        # Mover os embeddings para a CPU
        global_attention_embedding = global_attention_embedding.cpu()
        output_mean_embedding = output_mean_embedding.cpu()

        # Sincronizar CUDA para garantir que a GPU terminou o processamento antes de prosseguir
        torch.cuda.synchronize()

        # Limpar variáveis não utilizadas e liberar memória da GPU
        del inputs, attention_mask, global_attention_mask, outputs
        torch.cuda.empty_cache()

        return global_attention_embedding, output_mean_embedding

# Listas para armazenar embeddings
ga_embeddings = []
om_embeddings = []

# Processar as amostras
for item in sampled_data:
    ga_embedding, om_embedding = process_text(item['text'])

    # Adicionar embeddings às listas
    ga_embeddings.append(ga_embedding)
    om_embeddings.append(om_embedding)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %% [markdown]
# Verificando os textos próximos utilizando a similiaridade de cosseno

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def evaluate_similarity(embeddings, query_index=0, top_n=20):
    # Converter listas de embeddings para numpy arrays 2D
    embeddings = np.array([embedding.squeeze().numpy() for embedding in embeddings])  # Converter para 2D

    # Pegar o embedding do texto de interesse (query_index)
    query_embedding = embeddings[query_index]

    # Calcular a similaridade de cosseno entre o texto de interesse e todos os outros
    similarities = cosine_similarity([query_embedding], embeddings)

    # Classificar os textos por similaridade (em ordem decrescente)
    ranked_indices = np.argsort(similarities[0])[::-1]

    # Retornar os top_n textos mais semelhantes
    return ranked_indices[:top_n], similarities[0][ranked_indices[:top_n]]

print("GLOBAL ATTENTION EMBEDDING\n")

top_indices, top_similarities = evaluate_similarity(ga_embeddings)

for i in range(len(top_indices)):
    print(f"Texto {top_indices[i]}: Similaridade = {top_similarities[i]}\n{sampled_data[top_indices[i]]['text']}\n\n")

print("\nOUTPUT MEAN EMBEDDING\n")

top_indices, top_similarities = evaluate_similarity(om_embeddings)

for i in range(len(top_indices)):
    print(f"Texto {top_indices[i]}: Similaridade = {top_similarities[i]}\n{sampled_data[top_indices[i]]['text']}\n\n")
# Out:
# GLOBAL ATTENTION EMBEDDING
#
# Texto 0: Similaridade = 0.9999998211860657
# O gado está destruindo a nascente em Nordeste, pisoteando a área e acabando com a vegetação ao redor.
#
#
# Texto 102: Similaridade = 0.9999998211860657
# O gado está destruindo a nascente em Nordeste, pisoteando a área e acabando com a vegetação ao redor.
#
#
# Texto 26: Similaridade = 0.9999998211860657
# O gado está destruindo a nascente em Nordeste, pisoteando a área e acabando com a vegetação ao redor.
#
#
# Texto 40: Similaridade = 0.999997079372406
# O gado está destruindo a nascente em Sudeste, pisoteando a área e acabando com a vegetação ao redor.
#
#
# Texto 153: Similaridade = 0.999997079372406
# O gado está destruindo a nascente em Sudeste, pisoteando a área e acabando com a vegetação ao redor.
#
#
# Texto 114: Similaridade = 0.9999921321868896
# O gado está destruindo a nascente em Norte, pisoteando a área e acabando com a vegetação ao redor.
#
#
# Texto 106: Similaridade = 0.9999880194664001
# O gado está destruindo a nascente em Sul de Minas, pisoteando a área e acabando com a vegetação ao redor.
#
#
# Texto 60: Similaridade = 0.9999880194664001
# O gado está destruindo a nascente em Sul de Minas, pisoteando a área e acabando com a vegetação ao redor.
#
#
# Texto 82: Similaridade = 0.9999793171882629
# Aqui no Fazenda Esperança, o gado tá bebendo direto do rio, e a vegetação ciliar já foi toda destruída.
#
#
# Texto 56: Similaridade = 0.9999731779098511
# O gado está destruindo a nascente em Centro-Oeste, pisoteando a área e acabando com a vegetação ao redor.
#
#
# Texto 132: Similaridade = 0.9999731183052063
# Aqui no Fazenda Bela Vista, o gado tá bebendo direto do rio, e a vegetação ciliar já foi toda destruída.
#
#
# Texto 27: Similaridade = 0.9999455809593201
# Aqui em Centro-Oeste, o veneno que jogam nas plantações tá indo parar nas casas do pessoal.
#
#
# Texto 174: Similaridade = 0.9999388456344604
# Na lavoura de eucalipto em Rio Branco, os trabalhadores estão sem nenhum equipamento de proteção para aplicar os venenos.
#
#
# Texto 34: Similaridade = 0.9999384880065918
# Aqui na região de Nordeste, as nascentes tão todas sendo envenenadas pelos agrotóxicos que jogam na roça.
#
#
# Texto 87: Similaridade = 0.9999384880065918
# Aqui na região de Nordeste, as nascentes tão todas sendo envenenadas pelos agrotóxicos que jogam na roça.
#
#
# Texto 164: Similaridade = 0.9999324679374695
# Queimada ilegal em uma fazenda próxima a Nordeste, está destruindo a flora local e ameaçando animais selvagens.
#
#
# Texto 6: Similaridade = 0.9999222755432129
# Aqui na região de Sul de Minas, as nascentes tão todas sendo envenenadas pelos agrotóxicos que jogam na roça.
#
#
# Texto 11: Similaridade = 0.9999092221260071
# Queimada ilegal em uma fazenda próxima a Sudeste, está destruindo a flora local e ameaçando animais selvagens.
#
#
# Texto 137: Similaridade = 0.9999026656150818
# Aqui na fazenda Sítio da Paz, desmataram a nascente para plantar milho. Isso vai secar tudo!
#
#
# Texto 193: Similaridade = 0.9999026656150818
# Aqui na fazenda Sítio da Paz, desmataram a nascente para plantar milho. Isso vai secar tudo!
#
#
#
# OUTPUT MEAN EMBEDDING
#
# Texto 0: Similaridade = 1.0000001192092896
# O gado está destruindo a nascente em Nordeste, pisoteando a área e acabando com a vegetação ao redor.
#
#
# Texto 26: Similaridade = 1.0000001192092896
# O gado está destruindo a nascente em Nordeste, pisoteando a área e acabando com a vegetação ao redor.
#
#
# Texto 102: Similaridade = 1.0000001192092896
# O gado está destruindo a nascente em Nordeste, pisoteando a área e acabando com a vegetação ao redor.
#
#
# Texto 153: Similaridade = 0.9999849796295166
# O gado está destruindo a nascente em Sudeste, pisoteando a área e acabando com a vegetação ao redor.
#
#
# Texto 40: Similaridade = 0.9999849796295166
# O gado está destruindo a nascente em Sudeste, pisoteando a área e acabando com a vegetação ao redor.
#
#
# Texto 114: Similaridade = 0.9999816417694092
# O gado está destruindo a nascente em Norte, pisoteando a área e acabando com a vegetação ao redor.
#
#
# Texto 60: Similaridade = 0.999966025352478
# O gado está destruindo a nascente em Sul de Minas, pisoteando a área e acabando com a vegetação ao redor.
#
#
# Texto 106: Similaridade = 0.999966025352478
# O gado está destruindo a nascente em Sul de Minas, pisoteando a área e acabando com a vegetação ao redor.
#
#
# Texto 56: Similaridade = 0.9999655485153198
# O gado está destruindo a nascente em Centro-Oeste, pisoteando a área e acabando com a vegetação ao redor.
#
#
# Texto 132: Similaridade = 0.9998906254768372
# Aqui no Fazenda Bela Vista, o gado tá bebendo direto do rio, e a vegetação ciliar já foi toda destruída.
#
#
# Texto 82: Similaridade = 0.9998657703399658
# Aqui no Fazenda Esperança, o gado tá bebendo direto do rio, e a vegetação ciliar já foi toda destruída.
#
#
# Texto 57: Similaridade = 0.9998497366905212
# Queimada ilegal em uma fazenda próxima a Centro-Oeste, está destruindo a flora local e ameaçando animais selvagens.
#
#
# Texto 167: Similaridade = 0.9998368620872498
# Aqui no Fazenda Nova, o gado tá bebendo direto do rio, e a vegetação ciliar já foi toda destruída.
#
#
# Texto 76: Similaridade = 0.9998234510421753
# Queimada ilegal em uma fazenda próxima a Norte, está destruindo a flora local e ameaçando animais selvagens.
#
#
# Texto 177: Similaridade = 0.9998234510421753
# Queimada ilegal em uma fazenda próxima a Norte, está destruindo a flora local e ameaçando animais selvagens.
#
#
# Texto 164: Similaridade = 0.9998174905776978
# Queimada ilegal em uma fazenda próxima a Nordeste, está destruindo a flora local e ameaçando animais selvagens.
#
#
# Texto 11: Similaridade = 0.999812662601471
# Queimada ilegal em uma fazenda próxima a Sudeste, está destruindo a flora local e ameaçando animais selvagens.
#
#
# Texto 13: Similaridade = 0.9997997283935547
# Tão trabalhando sem proteção nenhuma na fazenda Fazenda Esperança, jogando veneno na lavoura. É um perigo!
#
#
# Texto 43: Similaridade = 0.9997997283935547
# Tão trabalhando sem proteção nenhuma na fazenda Fazenda Esperança, jogando veneno na lavoura. É um perigo!
#
#
# Texto 2: Similaridade = 0.9997541904449463
# Queimaram tudo aqui na fazenda do Fazenda Esperança pra aumentar o espaço pro gado. Já aconteceu ano passado.
